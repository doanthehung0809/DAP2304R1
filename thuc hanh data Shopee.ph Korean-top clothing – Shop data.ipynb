# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\Gymcode\DA\DAP2304R1\Data\shopeep_koreantop_clothing_shop_data.csv")

# %%
df.head()
# Out:
#              pk_shop date_collected     shopid                  name  \
# 0  20210613254711738     2021-06-13  254711738          hello.may.ph
# 1  20210613314198143     2021-06-13  314198143       love.women.shop
# 2   2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3   2021061321407329     2021-06-13   21407329           patriciacai
# 4   2021061311187885     2021-06-13   11187885  Little Market Manila
#
#   join_month  join_day  join_year  item_count  follower_count response_time  \
# 0      April        27       2020         446           17487      10:13:55
# 1  September        25       2020         263            8574      10:43:05
# 2  September        27       2016         209          660417      08:32:07
# 3      April        30       2017         165           18787      09:10:38
# 4    October        18       2016         467           67371      11:40:59
#
#    response_rate               shop_location  rating_bad  rating_good  \
# ...

# %%
df1 = df.copy()

# %%
city = lambda x:str(x).split(',')[-1]
df1['City'] = df['shop_location'].apply(city)
df1
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
df1['City'].unique()
# Out:
# array(['nan', 'Metro Manila', 'Rizal', 'Ilocos Sur', 'Laguna', 'Cavite',
#        'Batangas', 'Iloilo', 'Nueva Ecija', 'Pampanga', 'Albay', 'Bataan',
#        'Bulacan'], dtype=object)

# %%
# loc du lieu
df2 = df1[['pk_shop','shopid','join_month']]
df2[df2['join_month']!='April']
# Out:
#                pk_shop     shopid join_month
# 1    20210613314198143  314198143  September
# 2     2021061310377223   10377223  September
# 4     2021061311187885   11187885    October
# 6    20210613310915998  310915998  September
# 7    20210613126018720  126018720   February
# ..                 ...        ...        ...
# 741  20210706449182992  449182992        May
# 742  20210706396605392  396605392      March
# 743  20210706360379308  360379308   December
# 744   2021070629392066   29392066     August
# 745   2021070625811092   25811092       June
#
# [672 rows x 3 columns]

# %%
# tao cot moi voi nhieu dieu kien join_day>27 va join_year>2020
df3 = df1[(df1['join_day']>28) & (df1['join_year']>2020)]
df3
# Out:
#                pk_shop date_collected     shopid                      name  \
# 474  20210628455548857     2021-06-28  455548857              mr.monkey.ph
# 601  20210706412536354     2021-07-06  412536354  JK Women's Shopping Mall
# 659  20210706412764444     2021-07-06  412764444                la6rsf90hp
# 687  20210706455548857     2021-07-06  455548857              mr.monkey.ph
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 474        May        31       2021         598              35      10:17:48
# 601      March        29       2021         518             526      08:59:39
# 659      March        29       2021          10             328      09:18:54
# 687        May        31       2021        1000              62      09:52:49
#
#      response_rate             shop_location  rating_bad  rating_good  \
# 474             96                       NaN           0            1
# ...

# %%
df1
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
# thuc hanh tren bo du lieu gom: date_collected,response_time, shop_location
df3 = df1[['date_collected','response_time', 'shop_location']]
df3
# Out:
#     date_collected response_time               shop_location
# 0       2021-06-13      10:13:55                         NaN
# 1       2021-06-13      10:43:05    San Nicolas,Metro Manila
# 2       2021-06-13      08:32:07     Pasay City,Metro Manila
# 3       2021-06-13      09:10:38        Binondo,Metro Manila
# 4       2021-06-13      11:40:59  Caloocan City,Metro Manila
# ..             ...           ...                         ...
# 741     2021-07-06      08:45:30          Legazpi City,Albay
# 742     2021-07-06      08:01:23                         NaN
# 743     2021-07-06      08:46:30                         NaN
# 744     2021-07-06      12:19:44        Binondo,Metro Manila
# 745     2021-07-06      10:02:42     Pasay City,Metro Manila
#
# [746 rows x 3 columns]

# %%
# tach thanh cot ngay, thang, nam, gio, phut, giay rieng
df3['Day']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.day
df3['Month']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.month
df3['Year']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.year
df3['Hour']=pd.to_datetime(df['response_time'],format=' %H:%M:%S').dt.hour
df3['Minute']=pd.to_datetime(df['response_time'],format=' %H:%M:%S').dt.minute
df3['Second']=pd.to_datetime(df['response_time'],format=' %H:%M:%S').dt.second
df3
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12228\1457571400.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Day']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.day
# C:\Users\admin\AppData\Local\Temp\ipykernel_12228\1457571400.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Month']=pd.to_datetime(df['date_collected'],format='%Y-%m-%d').dt.month
# C:\Users\admin\AppData\Local\Temp\ipykernel_12228\1457571400.py:4: SettingWithCopyWarning:
# ...
